# %%
import numpy as np
import matplotlib.pyplot as plt 
from ezplot import plot_defaults
from glob import glob 
from pathlib import Path

def read_line_value(file_path: Path, line_num: int) -> float:
    with open(file_path, "r") as f:
        line_str = f.readlines()[line_num]
    value = float(line_str.split()[1])
    return value
T = []
lat_a = []
lat_b = []
lat_c = []

fig, gs = plot_defaults(3,1)
ax1 = fig.add_subplot(gs[0])
ax2 = fig.add_subplot(gs[1])
ax3 = fig.add_subplot(gs[2])
for res_file in Path("./").glob("XYZ*.res"):
    T.append(int(res_file.stem.split("@")[-1][:-1]))
    lat_a.append(read_line_value(res_file, 29))
    lat_b.append(read_line_value(res_file, 30))
    lat_c.append(read_line_value(res_file, 31))
ax1.scatter(T, lat_a)
ax2.scatter(T, lat_b)
ax3.scatter(T, lat_c)
plt.setp(ax1.get_xticklabels(), visible=False)
plt.setp(ax2.get_xticklabels(), visible=False)
ax1.set_ylabel("$a$")
ax2.set_ylabel("$b$")
ax3.set_ylabel("$c$")
plt.savefig("TB3Ni_lattice_parameter_vs_T.pdf")

# %%
import numpy as np
import matplotlib.pyplot as plt 
from ezplot import plot_defaults
from glob import glob 
from pathlib import Path

def read_line_value(file_path: Path, line_num: int) -> float:
    with open(file_path, "r") as f:
        line_str = f.readlines()[line_num]
    value = float(line_str.split()[1])
    return value
T = []
lat_a = []
lat_b = []
lat_c = []
lat_d = []
fig, gs = plot_defaults(3,1)
ax1 = fig.add_subplot(gs[0])
ax2 = fig.add_subplot(gs[1])
ax3 = fig.add_subplot(gs[2])
for res_file in Path("./").glob("XYZ*.res"):
    T.append(int(res_file.stem.split("@")[-1][:-1]))
    lat_a.append(read_line_value(res_file, 11))
    lat_b.append(read_line_value(res_file, 41))
    lat_c.append(read_line_value(res_file, 42))
    lat_d.append(read_line_value(res_file, 42))
ax1.scatter(T, lat_a)
ax2.scatter(T, lat_b)
ax3.scatter(T, lat_c)
plt.setp(ax1.get_xticklabels(), visible=False)
plt.setp(ax2.get_xticklabels(), visible=False)
#plt.setp(ax3.get_xticklabels(), visible=False)
ax1.set_ylabel("$Rw$")
ax2.set_ylabel("Ord scale")
ax3.set_ylabel("Para scale")
plt.savefig("TB3Ni_Rw_ord_para_parameter_vs_T.pdf")

# %%
import numpy as np
import matplotlib.pyplot as plt 
from ezplot import plot_defaults
from glob import glob 
from pathlib import Path

def read_line_value(file_path: Path, line_num: int) -> float:
    with open(file_path, "r") as f:
        line_str = f.readlines()[line_num]
    value = float(line_str.split()[1])
    return value
T = []
lat_a = []
lat_b = []
lat_c = []
lat_d = []
fig, gs = plot_defaults(2,1)
ax1 = fig.add_subplot(gs[0])
ax2 = fig.add_subplot(gs[1])


for res_file in Path("./").glob("XYZ*.res"):
    T.append(int(res_file.stem.split("@")[-1][:-1]))
    lat_a.append(read_line_value(res_file, 40))
    lat_b.append(read_line_value(res_file, 32))
    lat_c.append(read_line_value(res_file, 33))

ax1.scatter(T, lat_a)
ax2.scatter(T, lat_b)
ax2.set_xlabel("T / K")
plt.setp(ax1.get_xticklabels(), visible=False)



ax1.set_ylabel("Nuclear scale")
ax2.set_ylabel("$\delta^2$")

plt.savefig("TB3Ni_nuc_d2_parameter_vs_T.pdf")
